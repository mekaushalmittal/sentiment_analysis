# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import random
random.seed(0)
# %matplotlib inline
import pickle

# Preprocessing Tools
from textblob import TextBlob
import re
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem.wordnet import WordNetLemmatizer
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer

#Model Selection and Validation
from sklearn.naive_bayes import MultinomialNB,BernoulliNB 
from sklearn.model_selection import train_test_split
from sklearn.pipeline import Pipeline
from sklearn.metrics import confusion_matrix, classification_report,accuracy_score

# %% [markdown]
# ### Preprocessing

# %% [markdown]
# #### Reading Data

# %%
def get_all_data():
    root = "data/"

    with open(root + "imdb_labelled.txt", "r") as text_file:
        data = text_file.read().split('\n')
         
    with open(root + "amazon_cells_labelled.txt", "r") as text_file:
        data += text_file.read().split('\n')

    with open(root + "yelp_labelled.txt", "r") as text_file:
        data += text_file.read().split('\n')

    return data

whole_data = get_all_data()

# %% [markdown]
# #### Removing punctuations, stopwords, and converting words to root form of words

# %%
# remove punctuatons and stopwords
def form_sentence(word):
    word_blob = TextBlob(word)
    return ' '.join(word_blob.words)

stop_words = stopwords.words('english')
j=0
for i in stop_words:
    if i == 'not' or i == "isn't":
        stop_words.pop(j)
    j+=1

# converting to root form
def normalization(word_list):
        lem = WordNetLemmatizer()
        normalized = []
        for word in word_list:
            normalized_text = lem.lemmatize(word,'v')
            normalized.append(normalized_text)
        return normalized
    
def preprocessing_data(data):
    processing_data = []
    for single_data in data:
        if len(single_data.split("\t")) == 2 and single_data.split("\t")[1] != "":
            tmp = single_data.split("\t")
            tmp[0] = form_sentence(tmp[0][:len(tmp[0])-1]).lower()
            word_tokens = word_tokenize(tmp[0]) 
            tmp[0] = [w for w in word_tokens if not w in stop_words]
            tmp[0] = normalization(tmp[0])
            s=''
            for w in tmp[0]:
                s += w + ' '
            tmp[0]=s
            processing_data.append(tmp)
            
    return processing_data

whole_data = preprocessing_data(get_all_data())

# %%
whole_data
# Out:
# [['slow-moving aimless movie distress drift young man ', '0'],
#  ['not sure lose flat character audience nearly half walk ', '0'],
#  ['attempt artiness black white clever camera angle movie disappoint become even ridiculous act poor plot line almost non-existent ',
#   '0'],
#  ['little music anything speak ', '0'],
#  ['best scene movie gerardo try find song keep run head ', '1'],
#  ["rest movie lack art charm mean 's emptiness work guess 's empty ", '0'],
#  ['waste two hours ', '0'],
#  ['saw movie today think good effort good message kid ', '1'],
#  ['bite predictable ', '0'],
#  ['love cast jimmy buffet science teacher ', '1'],
#  ['baby owls adorable ', '1'],
#  ["movie show lot florida 's best make look appeal ", '1'],
#  ['songs best muppets hilarious ', '1'],
#  ['cool ', '1'],
#  ['right case movie deliver everything almost right face ', '1'],
#  ['average act main person low budget clearly see ', '0'],
#  ['review long overdue since consider tale two sisters single greatest film ever make ',
#   '1'],
#  ["'ll put gem movie term screenplay cinematography act post-production edit direct aspect film-make ",
#   '1'],
#  ["'s practically perfect \x96 true masterpiece sea faux masterpieces ", '1'],
#  ['structure film easily tightly construct history cinema ', '1'],
#  ['think film something vitally important occur every minute ', '1'],
#  ['word content level film enough easily fill dozen film ', '1'],
#  ['anyone right mind ask anything movie ', '1'],
#  ["'s quite simply highest superlative form cinema imaginable ", '1'],
#  ['yes film require rather significant amount puzzle-solving piece fit together create beautiful picture ',
#   '1'],
#  ['short film certainly pull punch ', '0'],
#  ['graphics far best part game ', '0'],
#  ['number one best th game series ', '1'],
#  ['deserve strong love ', '1'],
#  ['insane game ', '1'],
#  ["massive level massive unlockable character 's massive game ", '1'],
#  ['waste money game ', '1'],
#  ['kind money waste properly ', '1'],
#  ['actually graphics good time ', '1'],
#  ['today graphics crap ', '0'],
#  ['say canada fun game aye ', '1'],
#  ['game rock ', '1'],
#  ['buy play enjoy love ', '1'],
#  ["'s pure brilliance ", '1'],
#  ['flick doom conception ', '0'],
#  ['idea lame take minor character mediocre pg-13 film make complete non-sequel change tone pg-rated family movie ',
#   '0'],
#  ["n't least bite interest ", '0'],
#  ["not confirm film would unfunny generic also manage give away entire movie 'm not exaggerate every moment every plot point every joke tell trailer ",
#   '0'],
#  ["'s not funny ", '0'],
#  ["even talented carrell ca n't save ", '0'],
#  ["co-star n't fare much better people like morgan freeman jonah hill ed helm waste ",
#   '0'],
#  ['story predictable lazy ', '0'],
#  ["real effect work presence animals integration scenes worst obvious blue/green-screen work 've ever see ",
#   '0'],
#  ["whatever cost much n't translate quality 's sure ", '0'],
#  ['film succeed despite perhaps obviously meagre budget ', '1'],
#  ["'m glad film n't go obvious choice lesser film certainly would ", '1'],
#  ['addition one lovely songs ever write french cancan also boast one cutest lead ladies ever grace screen ',
#   '1'],
#  ["'s hard not fall head-over-heels love girl ", '1'],
#  ["negative 's insipid enough cause regret another 2 hours life waste front screen ",
#   '0'],
#  ['long whiny pointless ', '0'],
#  ['recommend wait future efforts let one go ', '0'],
#  ['excellent cast story line performances ', '1'],
#  ['totally believable ', '1'],
#  ['anne heche utterly convince ', '1'],
#  ["sam shepard 's portrayal gung ho marine sober ", '1'],
#  ['sit rivet tv screen ', '1'],
#  ['give one resound 9 10 ', '1'],
#  ['think tom hanks good actor ', '1'],
#  ['enjoy read book children little ', '1'],
#  ['disappoint movie ', '0'],
#  ['one character totally annoy voice give feel fingernails chalkboard ', '0'],
#  ['totally unnecessary train/roller coaster scene ', '0'],
#  ['absolutely warmth charm scenes character ', '0'],
#  ['movie totally grate nerve ', '0'],
#  ["performances not improve improvisation actors twice much worry not whether 're deliver line well whether line good ",
#   '0'],
#  ['quite honestly often not good ', '0'],
#  ["often dialogue n't really follow one line another fit surround ", '0'],
#  ['crackle unpredictable youthful energy honestly find hard follow concentrate meander badly ',
#   '0'],
#  ['generally great things ', '1'],
#  ["would n't say 're worth 2 hours time though ", '0'],
#  ['suspense builders good cross line g pg ', '1'],
#  ['especially like non-cliche choices parent movies could predict dialog verbatim write movie make better selections ',
#   '1'],
#  ["want movie 's not gross give chill great choice ", '1'],
#  ['alexander nevsky great film ', '1'],
#  ['amaze film artist one important whoever live ', '1'],
#  ["'m glad pretentious piece n't plan dodge stratus big shots 's gon na help movie makers n't restrain movie business québec ",
#   '0'],
#  ["first movie 've give 10 years ", '1'],
#  ['ever movie need word-of-mouth promote ', '1'],
#  ['overall film interest thought-provoking ', '1'],
#  ['plus well-paced suit relatively short run time ', '1'],
#  ['give one look ', '1'],
#  ['give 10 ', '1'],
#  ['wind lion well write superbly act ', '1'],
#  ['true classic ', '1'],
#  ['actually turn pretty decent far b-list horror/suspense film go ', '1'],
#  ['definitely worth check ', '1'],
#  ['problem script ', '0'],
#  ['horrendous ', '0'],
#  ['nothing believable ', '0'],
#  ['suspense feel frustration retard girls ', '0'],
#  ['manna heaven terrific film predictable unpredictable time ', '1'],
#  ['scenes often funny occasionally touch character evaluate live go ', '1'],
#  ['cast veteran actors nostalgia trip ', '1'],
#  ["ursula burton 's portrayal nun touch funny time make fun nuns church ",
#   '1'],
#  ['look movie terrific cast good music include shirley jones rendition way look tonight uplift end give one try ',
#   '1'],
#  ["n't think disappoint ", '1'],
#  ['frankly cotton club unfaithful kind embarrass watch lane gere film bad ',
#   '0'],
#  ['act bad dialogs extremely shallow insincere ', '0'],
#  ['predictable even chick flick ', '0'],
#  ['politically correct ', '0'],
#  ['disappoint ', '0'],
#  ['thing really worth watch scenery house beautiful ', '1'],
#  ["love lane 've never see movie lousy ", '0'],
#  ['hour half wish could bring back ', '0'],
#  ["term write 's fresh bold ", '1'],
#  ['act help write along well maybe idiot-savant sister could play better real joy watch ',
#   '1'],
#  ["direct cinematography n't quite good ", '0'],
#  ['movie bore sometimes find occupy peak paper instead watch never happen columbo movie ',
#   '0'],
#  ['sometimes embarrass look away ', '0'],
#  ['direct seem pretentious ', '0'],
#  ['scenes oh-so-mature neighbour-girl misplace ', '0'],
#  ['generally line plot weaker average episode ', '0'],
#  ['scene debate whether not sack trumpeter falsely accuse murder pure horror really stupid ',
#   '0'],
#  ['applause give prelude however ', '1'],
#  ['really like ', '1'],
#  ['great film great director ', '1'],
#  ['movie edge seat make somewhat afraid go car end night ', '1'],
#  ['music film really nice ', '1'],
#  ["'d advise anyone go see ", '1'],
#  ['brilliant ', '1'],
#  ['10/10 ', '1'],
#  ['like movie way much ', '1'],
#  ['problem think actor play villain low rent michael ironside ', '0'],
#  ['rock world certainly must see anyone social physical outlets ', '1'],
#  ["however n't make fact overall tremendously bore movie ", '0'],
#  ["chemistry ben affleck sandra bullock film could n't understand would consider even leave wife-to-be chick supposedly knock ",
#   '0'],
#  ["several moments movie n't need excruciatingly slow move ", '0'],
#  ['poor remake best friends wed ', '0'],
#  ['great disappointment ', '0'],
#  ['not believe actors agree film ', '0'],
#  ['could not stand even watch long fear lose i.q ', '0'],
#  ['guess nobody network air dribble watch put ', '0'],
#  ["imdb rat go low 1 awful 's time get negative number case ", '0'],
#  ['saw mirrormask last night unsatisfactory experience ', '0'],
#  ['unfortunately inexperience direction mean scene scene pass little way dramatic tension conflict ',
#   '0'],
#  ['central theme film handle ineptly stereotypically depth imagination ', '0'],
#  ['pretty picture world not make piece work flaw core ', '0'],
#  ['hour half waste time follow bunch pretty high schoolers whine cry life ',
#   '0'],
#  ["ca n't relate hell barely understand ", '0'],
#  ['definitely cult classic well worth view share others ', '1'],
#  ['movie pure disaster story stupid edit worst see confuse incredibly ', '0'],
#  ['fish badly make underwater shots repeat thousand time film ', '0'],
#  ['truly truly bad film ', '0'],
#  ['act terrible write worse ', '0'],
#  ['possible way movie could redeem would mst3k fodder ', '0'],
#  ['pay much ', '0'],
#  ["also 's real treat see anthony quinn play crazy horse ", '1'],
#  ['bore ', '0'],
#  ['plot whatsoever ', '0'],
#  ['plot ', '0'],
#  ['horrible ', '0'],
#  ['worst hour half life oh gosh ', '0'],
#  ['walk theatre minutes get relief ', '0'],
#  ['hate movies like ', '0'],
#  ['yeah movie pretty much suck ', '0'],
#  ['plot storyline ', '0'],
#  ['go see movie bring pillow girlfriend/boyfriend keep occupy ', '0'],
#  ['awful ', '0'],
#  ["n't think 've ever go movie dislike much ", '0'],
#  ["good thing ticket cost five dollars would mad 'd pay 7.50 see crap ", '0'],
#  ["nobody identify character 're cardboard cutouts stereotype predictably reverse-stereotypes ",
#   '0'],
#  ["bad film bad write good actors ugly cartoon craft paul haggis people ca n't handle anything bold stroke storytelling picture paint crayon ",
#   '0'],
#  ['crash depress little nothing provoke emotion teach nothing already know racism prejudice bad things ',
#   '0'],
#  ["still like movie 's empowerment women 's not enough movies like one ", '1'],
#  ['brain attempt shut-down part primal impulse self-preservation ', '0'],
#  ["leave shatter experience watch 'film take good two hours fully recover ",
#   '0'],
#  ['movie join revenge boogeyman zombiez part hellish trinity horror film ',
#   '0'],
#  ['certainly not mean distinction good way ', '0'],
#  ['mean terrible way ', '0'],
#  ['film redeem feature ', '0'],
#  ['everything appal ', '0'],
#  ['artless camera-work endlessly present us ugliest set imaginable i.e ', '0'],
#  ['story beyond stupid ', '0'],
#  ['script script ', '0'],
#  ['kid annoy ', '0'],
#  ['lead man charisma-free ', '0'],
#  ['utterly without merit level akin torture ', '0'],
#  ["'ll even say \x96 torture ", '0'],
#  ['maybe would reasonable explanation atrocity ', '0'],
#  ['not pleasant voyage self-discovery ', '0'],
#  ['highly unrecommended ', '0'],
#  ["premise sound stupid 's ", '0'],
#  ["yes 's bad ", '0'],
#  ['nothing recommend ', '0'],
#  ['excellent performance ms ', '1'],
#  ["garbo show right bat talents could carry silent era want see silent work netflix n't seem stock ",
#   '1'],
#  ["'s also great see renowned silent screenwriter frances marion n't miss step go silent sound ",
#   '1'],
#  ['movie suffer write need suspense ', '0'],
#  ['many close up ', '0'],
#  ["movie seem drag heroes n't really work freedom ", '0'],
#  ['movie definitely average rent ', '0'],
#  ["'ll love ", '1'],
#  ['movie bad ', '0'],
#  ['bad ', '0'],
#  ['film way long ', '0'],
#  ['definitely one bad ones ', '0'],
#  ["movie receive great quality film 's age ", '1'],
#  ['john wayne incredible job young movie industry ', '1'],
#  ['screen presence shin think even though senior actors screen ', '1'],
#  ['think must see older john wayne film ', '1'],
#  ["really n't see anyone could enjoy movie ", '0'],
#  ["n't think 've ever see movie half bore self-indulgent piece junk ", '0'],
#  ["probably would better director n't spend movie showcasing art work really n't noteworthy ",
#   '0'],
#  ["another thing n't really like character get punch face gallon blood would spew forth soon ",
#   '0'],
#  ['jamie foxx absolutely ray charles ', '1'],
#  ['performance simply genius ', '1'],
#  ["own film spacek own coal miner 's daughter quaid own great ball fire ",
#   '1'],
#  ["fact 's hard remember part ray charles act not play man ", '1'],
#  ['ray charles legendary ', '1'],
#  ['ray charles life provide excellent biographical material film go well beyond another movie musician ',
#   '1'],
#  ['hitchcock great director ', '1'],
#  ['ironically mostly find film total waste time watch ', '0'],
#  ['secondly hitchcock pretty much perfect thriller chase movie ', '1'],
#  ["'s pander audience sabotage film ", '0'],
#  ['hence whole story lack certain energy ', '0'],
#  ['plot simply rumble like machine desperately depend addition new scenes ',
#   '0'],
#  ['usual hitchcock logic flaw ', '0'],
#  ['mishima extremely uninteresting ', '0'],
#  ['chilly unremarkable movie author living/working chilly abstruse culture ',
#   '0'],
#  ["flat reenactments n't hold attention emotionally adrift stagy ", '0'],
#  ['rest sit awful soldier sing songs masculinity pledge hairsplitting purity admiration swords etc ',
#   '0'],
#  ['bore piece kill momentum movie quicker anyone else ', '0'],
#  ['schrader make resume full lousy amateurish film ', '0'],
#  ['first watch movie 80s love ', '1'],
#  ['totally fascinate music dance everything ', '1'],
#  ['however recently watch whole thing dvd completely strike extremely stupid storyline contain hole inconsistencies frankly whole lot crap horrid dance ',
#   '0'],
#  ['mean realistic world would never get ballet repertory whole thing quite pathetic ',
#   '0'],
#  ['character developments also lack depth ', '0'],
#  ['woa talk awful ', '0'],
#  ['not waste time ', '0'],
#  ['horrible ', '0'],
#  ['worst sappiest dialogue could go ', '0'],
#  ['really make unwatchable direction ', '0'],
#  ['poor actors ', '0'],
#  ["ca n't even tell talent not pathetic line speak director give action ",
#   '0'],
#  ["check director 's filmography site see film n't chance ", '0'],
#  ['would not even good make tv flick ', '0'],
#  ['good intentions make film great film might one greatest film ever make ',
#   '1'],
#  ['film great actors master director significant theme least would-be significant theme undertone fifties existential world-weariness aerial scenes ought thrill sense imagination character one might deeply care ',
#   '1'],
#  ['regrettably film fail ', '0'],
#  ['movie lack visual interest drama expression feel celebration patriotism underline narrative ',
#   '0'],
#  ['actress worse use june allison movie ', '0'],
#  ['yet enjoy watch ', '1'],
#  ['unfortunately bad movie plain bad ', '0'],
#  ['bad script bad direction horrible act make one plain bad ', '0'],
#  ['dialogue suck ', '0'],
#  ['cinematography-if call that-sucked ', '0'],
#  ['soundtrack suck ', '0'],
#  ['act suck ', '0'],
#  ['concert sequence suck ', '0'],
#  ['nice ', '1'],
#  ['funny ', '1'],
#  ['funny ', '1'],
#  ['overall movie cheap trash ', '0'],
#  ['movie not funny consider ridiculousness ', '0'],
#  ['come feel angry ', '0'],
#  ["spoilers whatever else ca n't say surface superbly craft ", '1'],
#  ['cinematography simply stun say least fx nothing not state-of-the-art ',
#   '1'],
#  ['conceptually show offer little bite everything everybody parent kid fantasy and/or fx fan ',
#   '1'],
#  ["n't single sour note strike acting-wise either surprisingly solid cast ",
#   '1'],
#  ['things consider job well do ', '1'],
#  ['thank good movie like do release ', '1'],
#  ['one best mexican movies ever one less understand even mexican matter identify felt ',
#   '1'],
#  ['rank highly great noir-crime-drama incredible performances belmondo lino ventura ',
#   '1'],
#  ['attention give every character complex psychological portrayals detail loyalty treachery love hope tremendous ',
#   '1'],
#  ['excellent drama excellent thriller excellent film ', '1'],
#  ['best melville ', '1'],
#  ['everything film simply incredible ', '1'],
#  ['truly take journey eye soul child ', '1'],
#  ["black water thriller manage completely transcend 's limitations 's indie flick continually subvert expectations emerge intense experience ",
#   '1'],
#  ["performances real grip crocdodile extremely well do indeed black water website believe 's use real crocs swamp location fabulous ",
#   '1'],
#  ['thoroughly enjoy christopher eccleston take control tardis continuation series ',
#   '1'],
#  ["'m not sure try film ", '0'],
#  ['turn good day feel night disturb memories guess succeed ', '0'],
#  ['lot beautiful place ', '1'],
#  ['force like everything movie ', '0'],
#  ['lame ', '0'],
#  ["'s movie really pi**ed ", '0'],
#  ["n't even get start jerky camerawork ", '0'],
#  ['saw theater think go sick ', '0'],
#  ["summary witticisms n't witty ", '0'],
#  ["plot well say 'd let one go ", '0'],
#  ['act bad ', '0'],
#  ['really bad ', '0'],
#  ["even billy bob could n't rise script worse ", '0'],
#  ['camerawork bad ', '0'],
#  ['rat 1 10 ', '0'],
#  ['amaze finale possibly best trilogy time ', '1'],
#  ['kieslowski never cease amaze ', '1'],
#  ['one favourite directors one talented directors history cinema ', '1'],
#  ['use colour french flag three film nothing short incredible every shoot every scene like work art ',
#   '1'],
#  ["three visually appeal movies 've ever see ", '1'],
#  ['subtle connections three film awesome ', '1'],
#  ['mention huge spoiler love end character three film remain survivors ferry disaster valentine young judge together old man watch tv solidify happiness suffer deal many years ',
#   '1'],
#  ["could n't think better way end film smile face great way wrap amaze film trilogy ",
#   '1'],
#  ['recommend everyone love film movies anything work art ', '1'],
#  ['10 10 movie trilogy ', '1'],
#  ['literally vomit watch film ', '0'],
#  ["think one people find another one roth 's pearl ", '1'],
#  ['performance award stun ', '1'],
#  ['story tell eloquently francis ford coppola 25 years earlier really unfold gradually leave room character develop ',
#   '1'],
#  ['wonderful location lie story contrast ', '1'],
#  ["beautiful direct film nicola 's roeg wih sublime cast ", '1'],
#  ["'m translate movies live first movie 5-year work experience find offensive intelligence ",
#   '0'],
#  ['someone strive greatness poetry deliver muddle often ridiculous story bunch disparate scenes pretentious dialogue get worst kind movie reviewer accurately define pretentious crap ',
#   '0'],
#  ["find movie intelligent even masterful say 's intelligence imagination obviously use try make sense pitiful attempt 's human nature try make sense things ",
#   '0'],
#  ["one thing tolerate political incorrectness well 'm artistic freedom suspension disbelief slavic female character much ",
#   '0'],
#  ['fun funny movie ', '1'],
#  ['highly entertain angle ', '1'],
#  ['feature outlandish array memorable psychotic lovable nut ', '1'],
#  ['enjoyment get see run around play game dangerous ', '1'],
#  ['even sweet moments ', '1'],
#  ['telephone repair man really funny reactions nut bitchy boss truly genuine ',
#   '1'],
#  ['character film tremendously well play ', '1'],
#  ['really find funny ', '1'],
#  ['actually smart movie ', '1'],
#  ['brilliant twist end ', '1'],
#  ['love ', '1'],
#  ["end perfect 'll shed tear ", '1'],
#  ['thrill see movie like ', '1'],
#  ['never forget ', '1'],
#  ['not cult cult classic ', '1'],
#  ['depth character man underneath ', '0'],
#  ['malta settings dry barren dialogue ', '0'],
#  ['movie terrible ', '0'],
#  ["hockey scenes terrible defensemen play like 're 5 years old goalies dive shots 10 feet wide net etc ",
#   '0'],
#  ["n't see n't waste time ", '0'],
#  ['call movie drama ridiculous ', '0'],
#  ["start watch n't believe character ", '0'],
#  ["particular relationship bakery assistant waitress n't work ", '0'],
#  ['superficial movie give feel watch play rather film ', '0'],
#  ["character 'stagey storyline lot like stage farce ", '0'],
#  ["time pyromaniac waylay assistant bore n't care happen next switch ", '0'],
#  ["glad n't pay see ", '0'],
#  ["n't laugh even smile ", '0'],
#  ["n't anything one big yawn ", '0'],
#  ['really good show watch ', '1'],
#  ['educational children 1 8 years old ', '1'],
#  ['barney definitely super de duper ', '1'],
#  ['pretty funny ', '1'],
#  ['babie bop cute ', '1'],
#  ['kid cool ', '1'],
#  ['storm trooper not even bad enough make list wonderfully terrible movies ',
#   '0'],
#  ["'s lame ", '0'],
#  ["guy say 's better dialogue pot plant right ", '0'],
#  ['everything movie stupid ', '0'],
#  ['even love bad movies not watch movie ', '0'],
#  ['shameful ', '0'],
#  ['would give television series 10 plus could ', '1'],
#  ['writers smack think best actors actresses bonus show.these character real ',
#   '1'],
#  ['must say tap episodes find watch ', '1'],
#  ['know give 10 ', '1'],
#  ["n't know exactly movie latch endear movie become special part family 's memories ",
#   '1'],
#  ['totally absolutely recommend movie anyone like good wholesome family movies exactly ',
#   '1'],
#  ['things four kid get absolutely hilarious watch ', '1'],
#  ['one best movies show strong sibling bond ', '1'],
#  ['much interest action suspense less unneeded controversy ', '1'],
#  ['everything act cinematography solid ', '1'],
#  ['definitely worth check ', '1'],
#  ['damian talented versatile many ways write portray different character screen ',
#   '1'],
#  ['movie cut edge ', '1'],
#  ['please know modern day genius let passion art drive take us audience ',
#   '1'],
#  ["new character n't memorable find forget ", '0'],
#  ['felt though go ireland absolutely nothing whatsoever ', '0'],
#  ["n't make scar horrify make sympathetic towards character simply annoy ",
#   '0'],
#  ['jerky camera movements also annoy ', '0'],
#  ['plot pretty much every cheap horror ', '0'],
#  ["pathetic attempt give character depth n't really work rest plot ", '0'],
#  ['guess suppose clever twist shed light situation stupid ', '0'],
#  ['see probably leave shelf ', '0'],
#  ['elias koteas jack palance play good roles angelina hot get naked.billy drago appear cool usual cameo sven ole thorsen help make enjoyable movie good act decent budget ',
#   '1'],
#  ['awesome movie buy ebay ', '1'],
#  ['really love story line poler bear kinda cute.but anyone question fort steele ask away ',
#   '1'],
#  ['totally unfunny movie top pathetic unrealistic throughout whole 90 minutes utter torture probably look watch 70000 time ',
#   '0'],
#  ['lucy bell much higher crap sink low quite depress ', '0'],
#  ['movie make sick watch slackers make excuse stupid action 90 minutes ', '0'],
#  ['god never get 90 minutes back ', '0'],
#  ['think wonderful part literally full wonder excerpt work ', '1'],
#  ['set especially design work camera amaze stylize beautiful effective ', '1'],
#  ['could use exemplars set designer ', '1'],
#  ['stories powerful explorations nature man art ', '1'],
#  ['watch film want learn work artist ', '1'],
#  ['highly recommend movie anyone interest art poetry theater politics japanese history ',
#   '1'],
#  ["wind lion see wonderful render america 's imperial age ", '1'],
#  ['make story different terrific production value faultless photography composition edit terrific cast underappreciated brian keith play bully teddy vivid history ',
#   '1'],
#  ["though wind lion tell largely eye son every member family identify one character whether sean connery 's noble brigand candace bergen 's feisty heroine john huston 's wily john hay steve kanaly 's spiffy radiant ruthless can-do lieutenant roosevelt 's big stick ",
#   '1'],
#  ['high adventure best ', '1'],
#  ['think robert ryans best film portray someone like father schizophrenic real life father although never murder anyone affect second world war make worse ',
#   '1'],
#  ['humour get get day apt ', '1'],
#  ['mother brother saw robert ryan portray type man good imitation type individual impress ',
#   '1'],
#  ['almost songs cover girl old-fashioned not tuneful ', '0'],
#  ["annoy thing 'cover girl way rita hayworth put pedestal ", '0'],
#  ["unfortunately 'cover girl example hollywood use exploit women financial gain ",
#   '0'],
#  ['non-linear narration thus many flashbacks every part articulate quite well ',
#   '1'],
#  ['good cinematography also make monica bellucci look beautiful ', '1'],
#  ["good commentary today 's love undoubtedly film worth see ", '1'],
#  ['people first timers film make think excellent job ', '1'],
#  ['popular cinema good house good reactions plenty laugh ', '1'],
#  ["'s feel-good film 's felt come cinema ", '1'],
#  ['northern humour positive community represent ', '1'],
#  ['rather enjoy ', '1'],
#  ['like ', '1'],
#  ["could n't take seriously ", '0'],
#  ['really create unique feel though ', '1'],
#  ['vivian schilling excellent job script ', '1'],
#  ['world better 95 garbage theatres today ', '1'],
#  ['role play well ', '1'],
#  ['not screamy not masculine right ', '1'],
#  ['camera really like movie ', '1'],
#  ['would cast role ready script ', '1'],
#  ["european movie nice throwback time student 1980 's experience live abroad interact nationalities although circumstances slightly different ",
#   '1'],
#  ['fan movie suck really bad ', '0'],
#  ['even worse ticker ', '0'],
#  ['movie bad ', '0'],
#  ['like 3 4 build use couple locations maybe poor hummh ', '0'],
#  ['blow ', '0'],
#  ["movie excellent angel beautiful scamp adorable little yelp hes scar funniest part scamp catch curtain angel scamp sing 'ive never feel before'.i totally recommend movie come special edition june 20.the cover scamp garbage angel underneath lid ",
#   '1'],
#  ['cant explain movie romantic charm hilarious adorable.the junkyard scenes funny junkyard dog something special.too funny laugh kid love it.buy come new feature ',
#   '1'],
#  ['choose torture disgust piece blatant american propaganda ', '0'],
#  ['show make americans stupid full hatred clichés admit elsewhere ', '0'],
#  ['almost everyone involve must return school act utterly predictable bad script pile garbage round ',
#   '0'],
#  ['wish could enter negative value admins ', '0'],
#  ["set bad would n't look place thunderbirds episode ", '0'],
#  ['use slow-motion needlessly repeat throughout movie well back bad act bad kind word continuity scenes throw reason whatsoever vehicles look like make corn flake box directorial style border stupidity ',
#   '0'],
#  ['oh yeah storyline pathetic ', '0'],
#  ["hate write bad review film especially really like star film bad n't believe one second anyone could proud ",
#   '0'],
#  ["not filmmaker director would hide head sand 'd spend whatever amount money time movie ",
#   '0'],
#  ['short monumental waste time energy would not recommend anyone ever see film ',
#   '0'],
#  ['come free dvd player buy still turn thing halfway embarrass howell ', '0'],
#  ['1/10 set 0/10 ', '0'],
#  ["interest premise billy drago always good dangerous nut-bag side note 'd love see drago stephen mchattie lance hendrikson flick together talk rag cheekbones ",
#   '1'],
#  ["soundtrack n't terrible either ", '1'],
#  ['act even professionals drago debbie rochon terrible direct worse perhaps contributory former dialog chimp-like camera work barely tolerable ',
#   '0'],
#  ['still set get big 10 oy-vey scale ', '1'],
#  ['yes simplify things sake brevity really core problems film much go without real fulfil explanation ',
#   '0'],
#  ['good job quite amuse ', '1'],
#  ["convolute plot n't convince much film watch weird question glance ", '0'],
#  ['let girlfriend talk see bad idea hat ', '0'],
#  ['last 15 minutes movie also not bad well ', '1'],
#  ['bela lugosi totally extraneous intone odd line ', '0'],
#  ['act decidely wooden though worse period universal b movie ', '0'],
#  ["like armand assante cable company 's summary sound interest watch twice already probably ",
#   '1'],
#  ['believe screenwriter good job tie loose end ', '1'],
#  ['8/10 score mostly plot ', '1'],
#  ["wo n't say n't like spoilers n't want one believe film worth time ", '1'],
#  ['wow bad film ', '0'],
#  ['not frighten least barely comprehensible ', '0'],
#  ["plot n't hang together act absolutely appal ", '0'],
#  ['not even good camp value ', '0'],
#  ["n't expect oscar material ", '0'],
#  ["'d iq particularly stupid mollusk not see one come ", '0'],
#  ['film use word loosely insult movie-going public ', '0'],
#  ['someone involve know string together narrative ', '0'],
#  ["get 1 10 simply 's nothing lower ", '0'],
#  ['one not watch recently fox movie channel disappoint ', '0'],
#  ['know contract player little control script act bad script ', '0'],
#  ['victor mclaglen even bad brian donlevy almost unrecognizable ', '0'],
#  ['consider relations screen taylor stanwyck surprise little chemistry screen two ',
#   '0'],
#  ['premise film ridiculous president u.s ', '0'],
#  ['death row scenes entirely unmoving ', '0'],
#  ["thing worse taylor 's act stanwyck 's sing ", '0'],
#  ['whatever producer go miss entirely ', '0'],
#  ['deeply impress character play ', '1'],
#  ['know saw film great things come gift actor ', '1'],
#  ['cheap cheerless heist movie poor characterisation lot underbite style stoic emote think chow yun fat better tomorrow cheesy clichés throw abandon factory ready poorly execute fly judo roll la john woo ',
#   '0'],
#  ['even squibs look awful ', '0'],
#  ['point proceed look remotely like america ', '0'],
#  ['plot derivative predictable end like mercy kill ', '0'],
#  ['awful dialogue hopeless overact everyone get shoot top real waste space time ',
#   '0'],
#  ['uneasy bad movie not scar ', '0'],
#  ['dialogue compose things make little sense ', '0'],
#  ['30 minutes footage waste show mediocre elderly actors awkwardly babble overwrought pseudo-satanic gibberish corny enough make teen goth blush almost always olde english sometimes latin may may not make word ',
#   '0'],
#  ['direct sloppy best ', '0'],
#  ['hackneyed write certainly make even worse bad direct ', '0'],
#  ['course act blah ', '0'],
#  ['act whole cast could put scale balance perfectly overact underact ', '0'],
#  ["finally get end would 've great handle competent people not jerry falwell ",
#   '0'],
#  ["love movie great portrayal family 's share up end know special love ", '1'],
#  ['see many movies star jaclyn smith god one best though come 12 years ago ',
#   '1'],
#  ["movie contain all-star cast love open eye see actors n't see ", '1'],
#  ['movie kind long length enjoy every minute ', '1'],
#  ['overall rate movie 10 1-10 scale ', '1'],
#  ['lifetime not air enough anyone know store sell let know must-have ', '1'],
#  ['particularly remember sense assault strident cord music would blare little warn even less mean ',
#   '0'],
#  ['sort pap screen afternoon punish unemployed not job ', '0'],
#  ['totally different load understatement black comedy film get see remember ',
#   '1'],
#  ['movie create universe fascinate every way ', '1'],
#  ['movie really get ', '1'],
#  ['see ', '1'],
#  ['really hope team behind movie make movies continue kinda weird style ',
#   '1'],
#  ["forget cast superb trond fausa aurvåg perfect role bothersome man n't understand ",
#   '1'],
#  ['movie good humorous comment life 2006 ', '1'],
#  ['find move beautiful enjoyable uplift ', '1'],
#  ['initially local sit film film buffalo intrigue ', '1'],
#  ['later find lose power film ', '1'],
#  ['entire audience applaud conclusion film ', '1'],
#  ['leave theater lilt step joy heart hope human race ', '1'],
#  ['duris wholesome appearance give fine performance ', '1'],
#  ['rest cast also play well ', '1'],
#  ['cinematography noteworthy include fine view barcelona famed gaudi tower ',
#   '1'],
#  ['ten minutes film start second thoughts ', '0'],
#  ['half way film start dislike ', '0'],
#  ['time film end not dislike despise ', '0'],
#  ['film lack convince script ', '0'],
#  ['script look rough draft write shoot begin finish script complete ', '0'],
#  ['things happen character personalities change plot twist occur real reason script call ',
#   '0'],
#  ['cast good ', '1'],
#  ["'s worth check ", '1'],
#  ['probably irritate show ever see entire life ', '0'],
#  ['indescribably annoy idiotic show ever see ', '0'],
#  ['everything bad ', '0'],
#  ['could not understand kind idiot would produce mess first place not mention several season ',
#   '0'],
#  ['script bad bad \x96 contain cheesiness unethical joke normally see rat r nc-17 movie ',
#   '0'],
#  ['cast also horrible cause see really really bad actors period ', '0'],
#  ['final word show real torture ', '0'],
#  ['zillion time away reality ', '0'],
#  ["watch wash machine twirl around would n't hurt eye much show ", '0'],
#  ['rat 0/10 grade z note show bad even mother cast pull daughter show ', '0'],
#  ["20th century fox 's road house 1948 not quite silly noir implausible unmitigated bore movie ",
#   '0'],
#  ['full unconvincing cardboard character blandly write edward chodorov also produce surprisingly direct jean negulesco one would expect great deal ',
#   '0'],
#  ['widmark character turn unintentionally comical ', '0'],
#  ['lose marble early proceed totally implausible unconvincing ', '0'],
#  ["n't enough mess movie picture also mar constant use studio set indoor exteriors ",
#   '0'],
#  ['whatever prompt documentary beyond ', '0'],
#  ['serious spoilers movie huge disappointment ', '0'],
#  ['many problems dont know start ', '0'],
#  ['cast great ', '1'],
#  ['steve martin deliver really funny performance middle-aged upper class uptight white guy ',
#   '1'],
#  ['add betty white jean smart great cast everyone play part really well ',
#   '1'],
#  ['movie make lot serious mistake ', '0'],
#  ['first enough racial stereotype racial joke offend everyone ', '0'],
#  ['movie litter overt racial slur towards black cast members return white depict morons boob ',
#   '0'],
#  ["put race card aside let look major flaw film destroy latifa 's character ",
#   '0'],
#  ['real plot ', '0'],
#  ['wouldnt see movie free ', '0'],
#  ['steamboat willie amazingly important film cinema history ', '1'],
#  ['second appearance mickey mouse follow silent plane crazy earlier year probably famous film mostly ground-breaking ',
#   '1'],
#  ["n't yet hear mickey speak tons sound effect music throughout film something take grant huge crowd pleaser 1928 ",
#   '1'],
#  ['however see short 25 years amaze timeless film actually ', '1'],
#  ["'s adorable see mickey play turkey straw highly imaginative occasionally cruel way ",
#   '1'],
#  ["clever real crowd-pleaser film still rank among mickey 's best film even 80 wonderful years ",
#   '1'],
#  ["bipolarity ruthless thug one minute ruthless killer next minute luv 's diaper commercial completely unconvincing ",
#   '0'],
#  ["'m terribly disappoint film would receive many award accolades especially far deserve work film ",
#   '0'],
#  ['original body soul 1947 masterpiece ', '1'],
#  ['john garfield ann revere lilli plmer william conrad canada lee film one greatest cinematographers ever grace screen..james wong howe ',
#   '1'],
#  ["n't think redeem qualities remake ", '0'],
#  ['may bad film ever make ', '0'],
#  ["bad well 's bad ", '0'],
#  ['movie solid example bad plot bad idea way ', '0'],
#  ["'s shame see good actors like thomerson jam make live mess like ", '0'],
#  ['think bad ', '0'],
#  ['film terrible credit 1986 version watchable ', '0'],
#  ["let 's start problems\x97the act especially lead professor bad ", '0'],
#  ['script big flaw mess ', '0'],
#  ["best example dumb write 's establish turn zombie-students back humans remove necklace contain piece meteorite ",
#   '0'],
#  ["director paul matthews also wrote/directed weak 1995 monster movie grim clearly n't know pace film ",
#   '0'],
#  ['movie terribly bore place ', '0'],
#  ['light awful ', '0'],
#  ['film look cheap bland ', '0'],
#  ['one disappoint aspects lack notable gore ', '0'],
#  ["convention never work well past certainly n't work ", '0'],
#  ['visual effect awful ', '0'],
#  ["cg open sequence space look like could create microsoft slideshow god 's sake ",
#   '0'],
#  ['explosion gas tank end awful ', '0'],
#  ["okay like consider fair critic 'll give credit credit 's due creature effect actually pretty cool ",
#   '1'],
#  ['get ta love close-ups slimy drool teeth ', '1'],
#  ['sum film breeders terrible cheaply make horror movie avoid like ebola virus ',
#   '0'],
#  ['not recommend ', '0'],
#  ['almost unbearable watch screen little charisma terrible comedic time ',
#   '0'],
#  ["aside 's terrible lead film load debit ", '0'],
#  ["understand 's suppose cheap popcorn comedy n't mean completely insult intelligence write incredibly hackneyed border offensive ",
#   '0'],
#  ["lewis black 's considerable talent waste incendiary unrestrained pg-13 rat certainly wo n't allow ",
#   '0'],
#  ["film 's sole bright spot jonah hill look almost unrecognizable fan recent superbad due amount weight lose interim ",
#   '1'],
#  ['originality freshness first movie spend remake little else offer ', '0'],
#  ['budget evidently limit ', '0'],
#  ['reflect not cast also below-par script borrow much earlier classic ', '0'],
#  ['however decent act action location work balance things ', '0'],
#  ['filmiing less expansive ', '0'],
#  ['fail convey broad sweep landscape great part original ', '0'],
#  ['generally lack imagination ', '0'],
#  ['not recommend ', '0'],
#  ['possible movie get worse ', '0'],
#  ['plot keep go first place ', '0'],
#  ['even women finally show sign improvement expect things happen time film might far asleep ',
#   '0'],
#  ['beware not trashy cult movie trash period ', '0'],
#  ["ca n't believe 's even sequel ", '0'],
#  ['precisely give bad review ', '0'],
#  ["90 's child truly enjoy show proudly say enjoy big time even classical wb cartoon ",
#   '1'],
#  ["tiny toons keep 90 's vibe deliver one popular funny underrate cartoon ever create ",
#   '1'],
#  ['memories murky say enjoy every single episode product relate show ', '1'],
#  ['easily none cartoon make laugh tender way get dark sitcoms orient teenagers ',
#   '1'],
#  ['character funny peculiarity not true lead character ', '1'],
#  ['every single character hilarious deserve call lead ', '1'],
#  ['every element story top excessively phony contrive painful sit ', '0'],
#  ['line seem write fifteen year old though try oh hard sound like fifteen year old would really um know well talk ',
#   '0'],
#  ['perabo nice energy level obviously comfortable front camera ', '1'],
#  ['simply excuse something poorly do ', '0'],
#  ['saw movie think stupid movie ', '0'],
#  ['even stupid think idea volcano los angeles ', '0'],
#  ['honest unbelievable nonsense foolish ', '0'],
#  ['conclusion not bother movie volcano los angeles nothing nonsense ', '0'],
#  ['story line awful ', '0'],
#  ["'s painful ", '0'],
#  ['accent absolutely abysmal ', '0'],
#  ["'s also enough hypocrisy film make vomit ", '0'],
#  ["n't waste time watch rubbish non-researched film ", '0'],
#  ['believe pitch black do well ', '1'],
#  ["character interest want find longer movie go think people surprise n't make ",
#   '1'],
#  ['go watch ', '1'],
#  ['omit watch ', '0'],
#  ['funny ', '1'],
#  ['rat 3 10 ', '0'],
#  ['character interest really care ', '1'],
#  ['instant classic great soundtrack catchy song end credit ', '1'],
#  ["n't miss ", '1'],
#  ["masterful piece film-make many theme simmer occasionally boil warts study poet 's bohemian self-indulgent wartime years span aerial bombardments london outward tranquillity welsh coastal retreat borderlines friendship lust love dedication art experience versus practical concern jealousy rivalry cowardice egotism versus heroism self-sacrifice ",
#   '1'],
#  ['mature subtle script suggest occasionally bring dramatic focus underlie tensions well serve perfect performances apart odd inappropriate smile keira knightley prone though perhaps direction time character often mention ',
#   '1'],
#  ['exquisite visual composition moment inventive elegant use close-up camera angle light include pointillistic faux home movie footage wonder joy behold ',
#   '1'],
#  ["'s continuously beautiful look bertolucci relationships convince narrative engage master 's work ",
#   '1'],
#  ['basic premise waste since sideline inexplicable focus documentary crew ',
#   '0'],
#  ['regardless film fail level ', '0'],
#  ['avoid cost ', '0'],
#  ['saw film christmas great film ', '1'],
#  ['think errol flynn brilliant custer since become favourite actor ', '1'],
#  ['act alongside olivia de havilland brilliant end fantastic ', '1'],
#  ['always know errol flynn brilliant actor dads favourite actor grow watch film child ',
#   '1'],
#  ["n't watch film realise great actually ", '1'],
#  ["'ll give film 10 10 ", '1'],
#  ["know jim o'connor energetic nobody could much george well dull ", '0'],
#  ["really n't seem want host voice-overs monotonous n't get involve guests ",
#   '0'],
#  ['lovely little thriller hitchcock lot nice shenanigans surround murder spy kidnap child nasty church foreign plot random taxidermists ',
#   '1'],
#  ["jimmy stewart ever great hero hitchcock story rip along cool climax embassy function lack brood menace hitchcock 's black white low-budget original ",
#   '1'],
#  ["nevertheless yet another wonderful film great master 's stable ", '1'],
#  ['say film excellently produce top rat typical sci fi film ', '1'],
#  ["excellently produce one sci-fi 's best producers scot vandiver ", '1'],
#  ['entertain nonetheless ', '1'],
#  ["'s campy sort film 's joy watch ", '1'],
#  ["'s barely bore moment film plenty humorous part ", '1'],
#  ['cast always entertain usual ', '1'],
#  ['overall delight ', '1'],
#  ["movie mind-bendingly awful could n't even create ", '0'],
#  ['film lack real scar tension medical terminology use throughout bite iffy say least say insulin dependant diabetic ',
#   '0'],
#  ['least say act better ', '0'],
#  ['movie excellent job reveal complexity task incredible challenge face south africa ',
#   '1'],
#  ['believe every one see movie think people outside south africa understand past attempt truth reconciliation process ',
#   '1'],
#  ['nothing short magnificent photography/cinematography film ', '1'],
#  ['act fantastic stories seamlessly weave together dog splendid must rent view see ',
#   '1'],
#  ["n't afraid subtitle worth little aversion therapy 10/10 ", '1'],
#  ['excellent performance ', '1'],
#  ['still good actors around ', '1'],
#  ['also great direct photography ', '1'],
#  ["true shakespear 'must shakespear fan ", '1'],
#  ['macbeth jason connery move tear final monolog brief candle give sphere moral decay dark force human face make interest ',
#   '1'],
#  ['helen baxendale credible lady macbeth cheerfull time sometimes look like naughty girl deadly taste blood evil ',
#   '1'],
#  ['love death decay shakespears lyric one ', '1'],
#  ["witty delightful adaptation dr seuss book brilliantly animate upa 's finest thoroughly deserve academy award ",
#   '1'],
#  ['special mention make superb music score sound effect integral element help make memorable enjoyable cartoon ',
#   '1'],
#  ['however paul schrader indeed make film mishima superb complex ', '1'],
#  ["also notable john bailey 's fine crisp beautifully color cinematography great production design costume eiko ishioka go memorable costume coppola 's dracula receive well deserve oscar ",
#   '1'],
#  ['even allow poor production value time 1971 format kind mini-series baaaaaad ',
#   '0'],
#  ["unless 're visually collect extant film austen 's work skip one ", '0'],
#  ["watch however small consolations actresses play anne 's sisters wonderful job roles ",
#   '1'],
#  ['not good ', '0'],
#  ['speak music unbearably predictably kitchy ', '0'],
#  ['film drop ball ', '0'],
#  ['stun movie ', '1'],
#  ['raw sublimely move ', '1'],
#  ["felt like grip intelligent stage play without overly theatrical feel one actually get watch people stage play everyone 's terror white lie escalate monstrous consequences ",
#   '1'],
#  ['main players mesmerise ', '1'],
#  ["tom wilkinson break heart end everyone else 's judge amount fumble hankies hand go face among males females alike ",
#   '1'],
#  ['julian fellowes triumph ', '1'],
#  ["'s national treasure ", '1'],
#  ['go see ', '1'],
#  ['excellent film ', '1'],
#  ['aerial scenes well-done ', '1'],
#  ['also right balance war love ', '1'],
#  ['film give mean phrase never history human conflict much owe many ', '1'],
#  ['kris kristoffersen good movie really make difference ', '1'],
#  ['good film great director ', '1'],
#  ['definitely one better documentaries see look family relationships marriage ',
#   '1'],
#  ["many continuity errors one user comment different cars garage joe 's glass one get fact joe 's facial hair configuration seem change scene scene ",
#   '0'],
#  ['great movie ', '1'],
#  ['10 10 star ', '1'],
#  ["ca n't see movie inspiration anyone come overcome fear rejection ", '0'],
#  ["'s bad 's actually worth see reason ", '0'],
#  ['punishment park brilliant piece cinema ', '1'],
#  ['shoot southern california desert use patent faux documentary style watkins create film like ',
#   '1'],
#  ['one peter watkins accessible film ', '1'],
#  ['advise look ', '1'],
#  ['wont regret ', '1'],
#  ['highly recommend ', '1'],
#  ['well keep think bad ', '0'],
#  ["'s mediocre miserable hollow laughable predictable piece garbage ", '0'],
#  ["'s case 'so bad laughable ", '0'],
#  ['bad performance play angela bennett computer expert home time ', '0'],
#  ['film nothing pretext show ridiculous action scenes ', '0'],
#  ['awful ', '0'],
#  ['still bad actress repeat robotic face move picture ', '0'],
#  ['result well shame ', '0'],
#  ['delete film mind ', '0'],
#  ['one worst show time ', '0'],
#  ['show would begin smart ass ed comment would totally wall uncalled ', '0'],
#  ['fat computer geek unbelievable bible thumper bad-ass girl actors ', '0'],
#  ['never hear except cole totally unbelievable part ', '0'],
#  ['every time open mouth expect hear see kid pull plug mercy kill horrible show ',
#   '0'],
#  ['stories unbelievable actors ', '0'],
#  ['lame would best way describe ', '0'],
#  ['stanwyck morgan perfectly cast many ways modern equivalent dickens christmas carol sensibility ',
#   '1'],
#  ['success film depend cast sydney greenstreet alexander yardley character ',
#   '1'],
#  ['attractive set use throughout film eye-pleasing gem ', '1'],
#  ['im big fan rpg game movie disgrace self-respecting rpger ', '0'],
#  ['line cut audio everything wrong ', '0'],
#  ['find better movies youtube ', '0'],
#  ["top line n't waste time money one bad come ", '0'],
#  ['lassie movie put sleep forever ', '0'],
#  ["'s 'd describe painfully dreary time-waster film ", '0'],
#  ["mediocre every aspect become dull uninteresting mess one forgettable movies 've see ",
#   '0'],
#  ["n't even achievement so-bad-it's-good so-bad-it's-memorable movie ", '0'],
#  ["'s empty hollow shell movie ", '0'],
#  ["seriously 's not worth waste kid 's time ", '0'],
#  ['avoid avoid avoid ', '0'],
#  ['drive bark mad ', '0'],
#  ['transfer good ', '1'],
#  ['nice relax late night view ', '1'],
#  ['movie full wonderful dance hence title ', '1'],
#  ['great music terrific scenery ', '1'],
#  ['handle tough issue dignity grace course shock spoiler ', '1'],
#  ['happy wonderful feel good end ', '1'],
#  ['point journey journey touch every member family ', '1'],
#  ["'s one movies need see whenever come tv never mind fact already memorize ",
#   '1'],
#  ['nothing new ', '0'],
#  ['do second movie ', '0'],
#  ['movie almost action scenes little comedy ', '0'],
#  ['plot hole pair fishnet stock direction edit astonishingly ham fisted ',
#   '0'],
#  ['earth iron film ', '0'],
#  ['saw film recommend ', '1'],
#  ['good plot hold complete attention act superb tom wilkinson fantastic emily watson also good ',
#   '1'],
#  ['good film indeed great unconditional love ', '1'],
#  ["tom wilkinson 's character man not prepare ordeal begin take matter hand story progress great actor give performance make feel character 's anguish suffer ",
#   '1'],
#  ["emily watson 's character strong give quick glance understand everything ",
#   '1'],
#  ['despite pan reviewers like movie ', '1'],
#  ["fact like better interview vampire like lestat stuart townsend better cruise 's attempt ",
#   '1'],
#  ['aailiyah pretty good akasha place compel first entrance mini dance scene ',
#   '1'],
#  ["'m big fan series mostly due anne rice 's style sensitivities treatments ",
#   '1'],
#  ['guess like detail dysfunction believable ', '1'],
#  ['football scenes end perplex ', '0'],
#  ['think act skilled ', '1'],
#  ['meredith better right ', '1'],
#  ['charm film wonderful sentiment heart ', '1'],
#  ["rare film-maker take time tell worthy moral tale care love n't fall trap overly syrupy indulgent ",
#   '1'],
#  ['nine ten truly lovely film ', '1'],
#  ['early film future goremeister lucio fulci good addition giallo sub-genre ',
#   '1'],
#  ["one best italian thrillers early 70 's ", '1'],
#  ['standout scene ', '1'],
#  ['scene strong unpleasant ', '0'],
#  ["technically film well make impressive camera-work solid act effective music riz ortolani \x96 particularly good recur unaccompanied female vocal sound like 's come distant hill ",
#   '1'],
#  ["'s still wild stuff though highly recommend fan giallo cinema ", '1'],
#  ['movie interest begin end ', '1'],
#  ["like way dustin hoffman 's character ready everything stay son ", '1'],
#  ['movie also reveal ', '1'],
#  ['personally think show people learn find compromise self without involve people issue ',
#   '1'],
#  ['bore ', '0'],
#  ['tire clichés lazy write come thick fast ', '0'],
#  ['ps scene movie cool central character find room blow ', '1'],
#  ["'s fresh subtle rather sublime effect ", '1'],
#  ["italian reviewer call small great film 's right ", '1'],
#  ['actors give wonderful performance especially jennifer rubin jamie harris change nervous starlet begin strange events part cool star ',
#   '1'],
#  ['learn lot real inside emotions people movie lot movie business ', '1'],
#  ['movie movie situations begin game play act coach fascinate ', '1'],
#  ["also music mark snow possibly best score 've ever hear ", '1'],
#  ["wo n't forget movie ", '1'],
#  ['film make ', '0'],
#  ['film ultra-cheap look ', '0'],
#  ["result film n't look right ", '0'],
#  ['none engage excite ', '0'],
#  ["plot nonsense n't interest slightest way uniqueness ", '0'],
#  ['foreigner not worth one second time ', '0'],
#  ['saw child tv back 1973 stranger love ', '1'],
#  ["duet astronaut doctor begin movie perfect exchange one consider movie make well cold war astronaut 's biggest fear crash ussr ",
#   '1'],
#  ['movie awesome ', '1'],
#  ['love really scary ', '1'],
#  ['love scream movies horror movies one rank way ', '1'],
#  ['want real scare rent one ', '1'],
#  ['10/10 ', '1'],
#  ['extraordinary film ', '1'],
#  ["courtroom drama 's compel indictment american justice system 's frighten ",
#   '1'],
#  ["film highlight fundamental flaw legal process 's not discover guilt innocence rather present better court ",
#   '1'],
#  ["film well pace understate one best courtroom documentaries 've see ", '1'],
#  ['mostly routine fact-based tv drama get boost fine performance cole ', '1'],
#  ['predictable not bad watch ', '1'],
#  ['clear range ability pull part ', '1'],
#  ['carry movie well ', '1'],
#  ['constantine give everything right intensity seem good understand underlie psychological motivations ',
#   '1'],
#  ['wonderful inspire watch hope get release video dvd ', '1'],
#  ["piece trash ever release beyond act story character supposedly special effect etc 's wrong ",
#   '0'],
#  ['fact stinker smell like direct-to-video release ', '0'],
#  ['avoid cost ', '0'],
#  ['star trek v final frontier worst series ', '0'],
#  ['act involve include like shatner nimoy bad wash make seem old look real life special effect tacky like spock rescue kirk jet pack fall mountain ',
#   '0'],
#  ["attempt humor pitiful story awful dose n't bear think basically involve vulcan steal enterprise find god seriously n't care film oh not mention uhura belly dance distract male guard ",
#   '0'],
#  ['place good film garbage ', '0'],
#  ['worst one series ', '0'],
#  ['edit edit film phenomenal opinion ', '1'],
#  ['song could explain emotions subject better jay adams unfortunate life subject talk song old man neil young play evoke many emotions ',
#   '1'],
#  ['cinematography film shoot interest way ', '1'],
#  ['course footage 70s grainy enhance film ', '1'],
#  ['film offer many delight surprise ', '1'],
#  ['achille philippa beautifully sing duet giovanni perfectly describe situation movie appreciate subtle layer excellent film ',
#   '1'],
#  ['story unfold 18th century jutland use period music play period instrument one fine touch ',
#   '1'],
#  ["share general loewenhielm 's exquisite joy partake cailles en sarcophage even though watch movie wish small sample savor ",
#   '1'],
#  ['understate film leave last impression ', '1'],
#  ['warmth generate contrast austere backdrop ', '1'],
#  ['leave theater want go dance star ', '1'],
#  ["act 'd expect cast top notch ", '1'],
#  ['character flesh surprisingly well particularly grime blake actors deliver sharply script line right amount deadpan tongue cheek make dialogue hilarious realistic ',
#   '1'],
#  ['angus scrimm also turn good performance somewhat brief memorable role gently menace violin-playing anatomist doctor quinn ',
#   '1'],
#  ['conclusion love ', '1'],
#  ["'s long time since entertain movie ", '1'],
#  ['struggle find anything bad say ', '1'],
#  ['mark word one cult film like evil dead 2 phantasm people still discover fall love 20 30 40 years line ',
#   '1'],
#  ["'s pretty surprise wonderful film make 1949 hollywood generally collective head sand concern black white issue time ",
#   '1'],
#  ["film deserve strong kudos take stand exceptional act mostly lesser-known cast super-intelligent script n't insult audience take easy way come white racism ",
#   '1'],
#  ["plus movie 's rather modest budget fast run time amaze job ", '1'],
#  ['juano hernandez exceptional actor play support roles many film era proud black man accuse murder white man south ',
#   '1'],
#  ['trumbull love lucy ', '1'],
#  ['see kid chance open amaze dialog far race relations come last 50 years ',
#   '1'],
#  ['see film ', '1'],
#  ["year however remind us huston still top game evince faithful adaptation jam joyce 's acclaim novella dead ",
#   '1'],
#  ["feel thoughts gabriel 's discomfort dance intangibles leap life come within viewer 's grasp huston 's portrayal ",
#   '1'],
#  ['disappoint wonder could oscar shortlist ', '0'],
#  ["'s slow ", '0'],
#  ["lot hole plot 's nothing become emperor nothing spend 20 years childhood mature age ",
#   '0'],
#  ["n't waste time ", '0'],
#  ["end days one worst big-budget action movies 've ever see ", '0'],
#  ["surely n't know make coherent action movie screenwriter air force one oblige write script big sum money ",
#   '0'],
#  ['one worst film ever see ', '0'],
#  ["'m still try get bad ", '0'],
#  ['movie possibly one creative work horror ever ', '1'],
#  ["everything could want suspense drama comedy confuse subplots native americans brain eat 're look be-all end-all brainsucking movies look ",
#   '1'],
#  ["great sound effect impressive special effect ca n't recommend movie enough ",
#   '1'],
#  ['call nut think one best movies ever ', '1'],
#  ['great character actors telly savalas peter boyle ', '1'],
#  ['1 hour 54 minutes sheer tedium melodrama horrible act mess script sink feel good lord think ',
#   '0'],
#  ['lot hole script ', '0'],
#  ["'s like bad two hour tv movie ", '0'],
#  ['imagine every single one decisions make wrong ', '0'],
#  ['dialogue atrocious ', '0'],
#  ['act beyond abysmal ', '0'],
#  ['everything stink ', '0'],
#  ['trouble write direct make impossible establish things make movie watchable like character story theme ',
#   '0'],
#  ["worse 's incredibly weak sub-plot throw follow little band latter-day mansonites go reporter 's work story anniversary kill ",
#   '0'],
#  ["'s dumb pointless complete waste time ", '0'],
#  ["short n't bother movie ", '0'],
#  ["wo n't spoil end pretty amaze ", '1'],
#  ["best scene movie end wo n't spoil ", '1'],
#  ["ever indication writer director 's ability meld two highly volatile temperaments seamless union creativity ",
#   '1'],
#  ["result powerhouse achievement make timely perhaps culture 's disturb fascination celebrity 's distort interpretations fame ",
#   '1'],
#  ['film not easily forget ', '1'],
#  ['kevin spacey excellent verbal tsunami buddy ackerman \x96 totally believable great actor ',
#   '1'],
#  ['script subtle comedy unmatched movie recent years ', '1'],
#  ['character interest even bite predictable ', '1'],
#  ['highly recommend age although younger set probably not appreciate subtle reference certainly appreciate one galley scene particular ',
#   '1'],
#  ['great movie ', '1'],
#  ['also story act weak ', '0'],
#  ["around 4 pm buy around 8pm start watch around 8.15pm fast forward remain film see anything leave watchable human brain n't ",
#   '0'],
#  ['either way suck ', '0'],
#  ['script horrendously stupid ', '0'],
#  ['story start fast absolutely suspense build-up slightest ', '0'],
#  ['everything captain howdy say either laughable plain stupid ', '0'],
#  ['hell kind crap ', '0'],
#  ["'s plot hole ", '0'],
#  ['could drive semi truck hole ', '0'],
#  ['linda cardellini thing good film ', '1'],
#  ["'s poise amaze ", '1'],
#  ['dee snider plain suck ', '0'],
#  ["ca n't act one least scary villains ever see ca n't write write damn movie sleep ",
#   '0'],
#  ['bore throughout whole damn thing ', '0'],
#  ['act suck music suck script suck pace suck special fx suck direct suck basically movie suck ',
#   '0'],
#  ['film try serious sophisticate thriller/horror flick fail miserably ', '0'],
#  ['probably one least effective utterly unoriginal film ever see entire life ',
#   '0'],
#  ['piece cinematic garbage capture celluloid ', '0'],
#  ['avoid cost ', '0'],
#  ['rate film stink not funny fulci stay giallo supernatural zombie movies ',
#   '0'],
#  ['avoid film cost ', '0'],
#  ["n't know happen season five mess ", '0'],
#  ['consistent thread hold series together amaze performances leni parker anita laselva two taelons quiet idealogical conflict ',
#   '0'],
#  ['movie really dislike ', '0'],
#  ["'s one bore horror movies 90 's mainly start slow center bore atmosphere ",
#   '0'],
#  ["puppets look really cheesy not good way like puppet master 80 's flick ",
#   '0'],
#  ['story lame not interest never really explain sinister origins puppets ',
#   '0'],
#  ["n't death scenes like previous movies f/x terrible ", '0'],
#  ['felt asleep first time watch recommend insomniacs ', '0'],
#  ['fact film wonderful heartwarming tale two people chase dream ', '1'],
#  ["best part nurse betty 's unpredictability ", '1'],
#  ['director neil labute use brutal violence seperate dream reality along touch drama hilarious comedy never tell go happen next ',
#   '1'],
#  ["otherwise n't even waste time ", '0'],
#  ['one fail create real suspense ', '0'],
#  ["killer n't expect anything original even remotely frighten ", '0'],
#  ['however pretty good act least type film ', '1'],
#  ["'m sorry really ca n't recommend anyone ", '0'],
#  ['one bore pointless movies ever see ', '0'],
#  ['secondary plot line incomprehensible relation primary plot line mystify ',
#   '0'],
#  ['hat ', '0'],
#  ['one worst sandra bullock movie since speed 2 not quite bad ', '0'],
#  ["n't understand garbage get shelve movie store 's not even real movie ",
#   '0'],
#  ['highly doubt anyone could ever like trash ', '0'],
#  ['not movie-making ', '0'],
#  ["act like watch wooden puppets move around read book 's bad ", '0'],
#  ['warn not rent movie dumbest thing never see ', '0'],
#  ['saw short film hbo day absolutely love ', '1'],
#  ["n't realize wonderful short really last two scenes ", '1'],
#  ['excellent short film ', '1'],
#  ['hopefully director jam cox turn short feature length film cast win us whole new film ',
#   '1'],
#  ['agree jessica movie pretty bad ', '0'],
#  ['character one-dimensional even good guy especially bad guy ', '0'],
#  ['story line totally predictable ', '0'],
#  ['not much dialogue not much music whole film shoot elaborately aesthetically like sculpture ',
#   '1'],
#  ["'ve see soap operas intelligent movie ", '0'],
#  ['bad character bad story bad act ', '0'],
#  ['really awful ', '0'],
#  ['not easy watch ', '0'],
#  ["funny clever hip like pray 's previous film hype ", '1'],
#  ["long time n't see charismatic actor screen ", '1'],
#  ['paolo sorrentino write wonderful story loneliness tony build one unforgettable character see movies recent years ',
#   '1'],
#  ["movie not completely perfect 'titta di girolamo stay long time vision movie ",
#   '1'],
#  ['rate movie 9/10 ', '1'],
#  ["not know emilio estevez 's directorial debut pace interplay development character well clever camera work surround character estevez play suggest natural eye ",
#   '1'],
#  ['interplay martin emilio contain wonderful chemistry saw wall street martin charlie ',
#   '1'],
#  ['kathy bat wonderful character subtle desperation escapism variation character play field lord ',
#   '1'],
#  ["readers already see one miyazaki 's film still top form make another worthwhile experience ",
#   '1'],
#  ['never condescend character good genuine hearts believable problems ', '1'],
#  ['two main character may two believable children ever saw put screen ', '1'],
#  ['easy love even easy identify ', '1'],
#  ['movie great especially enjoy visual arts ', '1'],
#  ['scenery two daughters paint photograph beautiful ', '1'],
#  ['story also funny poignant time ', '1'],
#  ['people like european film art movies like movie ', '1'],
#  ['truly art movie actually lot art ', '1'],
#  ['go rent ', '1'],
#  ['however finally watch film realize not close mind brilliance depict also find watch ',
#   '1'],
#  ["'s one movie never cease interest simply keep alert try attempt decipher 's mean ",
#   '1'],
#  ['brilliance indeed ', '1'],
#  ["like movies like matrix better yet sequels think 'll appreciate think provoke mindblowing experience film give ",
#   '1'],
#  ['think film like dream ', '1'],
#  ['simply beautiful ', '1'],
#  ['rickman stowe play roles hilt tale childrens book writer maybe write subversive tract ',
#   '1'],
#  ["'s gloriously fun fast pace fairly accurate portrayal night raver ", '1'],
#  ['present idyllic yet serious portrayal up down character live ', '1'],
#  ['whatever avoid groove antithesis good human traffic ', '0'],
#  ["'s bad everyone else involve n't share crowe 's level dedication quality 'd far better film hand sub-par mess ",
#   '0'],
#  ['movie seem little slow first ', '0'],
#  ['pick speed get right point ', '1'],
#  ['show exactly government scientist argue humanity reason gadget ', '1'],
#  ['enjoy ', '1'],
#  ['recommend friends ', '1'],
#  ['particularly please act ability dwight schultz ', '1'],
#  ['actors truly understand become particular character deliver convince sincere performance ',
#   '1'],
#  ['on-screen chemistry critical entire film genuine ', '1'],
#  ["film 's dialogue natural real life ", '1'],
#  ['writer gorman bechard undoubtedly homework reference industry character-age appropriate ',
#   '1'],
#  ['incredible soundtrack truly capture essence film ', '1'],
#  ['track command sentiment actually contribute scenes character ', '1'],
#  ["definitely worth see 's sort think provoke film force question threshold loneliness ",
#   '1'],
#  ["hayao miyazaki 's latest eighth film studio ghibili gake ue ponyo ponyo cliff sea wonderfully fun imaginative look childhood ",
#   '1'],
#  ["time seem film animation dominate disney/pixar 's cgi masterpieces refresh comfort know miyazaki still rely traditional hand-drawn animation tell charm enchant stories ",
#   '1'],
#  ['enough not say remarkable animation film ', '1'],
#  ['art style appearance crayon/pencil draw wonderfully colorful fanciful ',
#   '1'],
#  ["act film glad 're gon na drift away earth far possible ", '0'],
#  ['one want surf small wave space movies 1998 deep impact armageddon one fail everywhere ',
#   '0'],
#  ["n't choke vomit end cheap drama worthless dialogue 've must bore death waste time ",
#   '0'],
#  ['still make super end depict great sea vessel take mighty frost ', '1'],
#  ['consider excellent story solid act look film add bonuses ', '1'],
#  ['instead get bore fest whiny spoil brat babysitting ', '0'],
#  ['watch two sundays ago march 20th 2005 begin really enjoy time tap entire thing ',
#   '1'],
#  ['well act do tv movie ', '1'],
#  ['judith light one favorite actresses think superb job film ', '1'],
#  ['keep watch ', '1'],
#  ["'s sad movie good ", '1'],
#  ['not see movie definitely recommend ', '1'],
#  ['lovely usual cutie ', '1'],
#  ["still 's quite interest entertain follow ", '1'],
#  ['recommend confidence ', '1'],
#  ['movie well-balanced comedy drama thoroughly enjoy ', '1'],
#  ['riot see hugo weave play sex-obsessed gay real estate salesman use clients house trysts flame darren tom hollander ',
#   '1'],
#  ['anyway plot flow smoothly male-bonding scenes hoot ', '1'],
#  ['open sequence gem classic cat n mouse game follow delight watch ', '1'],
#  ['fan genre heaven ', '1'],
#  ['lange become great actress ', '1'],
#  ['look like wonderful story ', '1'],
#  ['never walk movie faster ', '0'],
#  ['get bore watch jessice lange take clothe ', '0'],
#  ["unfortunately virtue film 's production work lose regrettable script ",
#   '0'],
#  ['word embarrass ', '0'],
#  ['exceptionally bad ', '0'],
#  ["insult one 's intelligence huge waste money ", '0'],
#  ...]

# %% [markdown]
# #### Test-Train Split

# %%
def split_data(data):
    total = len(data)
    #  split with train 85%   
    training_ratio = 0.85
    training_data = []
    evaluation_data = []
    random.shuffle(data)
    

    for indice in range(0, total):
        if indice < total * training_ratio:
            training_data.append(data[indice])
        else:
            evaluation_data.append(data[indice])

    return training_data, evaluation_data

train, val = split_data(whole_data)

# %%
train_text = [data[0] for data in train]
train_result = [ord(data[1])-ord('0') for data in train]
val_text = [data[0] for data in val]
val_result = [ord(data[1])-ord('0') for data in val]

# %% [markdown]
# #### Tfidf vectorization

# %%
vectorizer = TfidfVectorizer()
train_text = vectorizer.fit_transform(train_text)
# val_text = vectorizer.transform(val_text)

# %% [markdown]
# ### Model and Training

# %%
def training_step(text, result):
    return MultinomialNB().fit(text, result)

# %%
classifier = training_step(train_text, train_result)
result = classifier.predict(vectorizer.transform(["I love this movie!"]))

result
# Out:
# array([1])

# %% [markdown]
# ### Evaluation

# %%
def analyse_text(classifier, vectorizer, text):
    return text, classifier.predict(vectorizer.transform([text]))
  
def print_result(result):
    text, analysis_result = result
    print_text = "Positive" if analysis_result[0] == 1 else "Negative"
    print(text, ":", print_text)

# %%
print_result(analyse_text(classifier, vectorizer, "this is a good movie"))
# Out:
# this is a good movie : Positive

# %% [markdown]
# #### Running on Validation Data

# %%
def simple_evaluation(evaluation_text, evaluation_result, vectorizer):
    total = len(evaluation_text)
    corrects = 0
    for index in range(total):
        analysis_result = analyse_text(classifier, vectorizer, evaluation_text[index])
        text, result = analysis_result
        corrects += 1 if result[0] == evaluation_result[index] else 0

    return corrects * 100 / total

simple_evaluation(val_text, val_result, vectorizer)
# Out:
# 85.11111111111111

# %% [markdown]
# #### Confusion Matrix

# %%
def create_confusion_matrix(evaluation_text, actual_result, vectorizer):
    prediction_result   = []
    for text in evaluation_text:
        analysis_result = analyse_text(classifier, vectorizer, text)
        prediction_result.append(analysis_result[1][0])
    
    matrix = confusion_matrix(actual_result, prediction_result)
    return matrix

confusion_matrix_result = create_confusion_matrix(val_text, val_result, vectorizer)

# %%
pd.DataFrame(
    confusion_matrix_result, 
    columns=["Negatives", "Positives"],
    index=["Negatives", "Positives"])
# Out:
#            Negatives  Positives
# Negatives        199         26
# Positives         41        184
